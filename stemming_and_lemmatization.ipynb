# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\yashvi khatri\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\yashvi khatri\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\yashvi khatri\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\yashvi khatri\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\yashvi khatri\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\yashvi khatri\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\YASHVI KHATRI\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\YASHVI KHATRI\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\YASHVI KHATRI\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
import nltk
import spacy

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting"]

for word in words:
    print(word, "|", stemmer.stem(word))
# Out:
# eating | eat
# eats | eat
# eat | eat
# ate | ate
# adjustable | adjust
# rafting | raft
# ability | abil
# meeting | meet

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("eating eats eat ate adjustable rafting ability meeting better")

for token in doc:
    print(token, "|", token.lemma_, "|", stemmer.stem(token))
# Out:
# eating | eat | 9837207709914848172
# eats | eat | 9837207709914848172
# eat | eat | 9837207709914848172
# ate | eat | 9837207709914848172
# adjustable | adjustable | 6033511944150694480
# rafting | raft | 7154368781129989833
# ability | ability | 11565809527369121409
# meeting | meeting | 14798207169164081740
# better | well | 4525988469032889948

# %%
doc = nlp("Mando talked for 3 hours although talking isn't his thing")

for token in doc:
    print(token, "|", token.lemma_)
# Out:
# Mando | Mando
# talked | talk
# for | for
# 3 | 3
# hours | hour
# although | although
# talking | talk
# is | be
# n't | not
# his | his
# thing | thing

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
ar = nlp.get_pipe('attribute_ruler')
ar.add([[{"TEXT": "Bro"}], [{"TEXT": "Brah"}]], {"LEMMA": "Brother"})

doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")

for token in doc:
    print(token.text, "|", token.lemma_)
# Out:
# Bro | Brother
# , | ,
# you | you
# wanna | wanna
# go | go
# ? | ?
# Brah | Brother
# , | ,
# do | do
# n't | not
# say | say
# no | no
# ! | !
# I | I
# am | be
# exhausted | exhaust

# %%
doc[0]
# Out:
# Bro

# %%
doc[0].lemma_
# Out:
# 'Brother'
